# %%
# !pip install numpy

# %%
import numpy as np
import matplotlib.pyplot as plt


N=100000
p=0.6
x=np.random.uniform(0,1,N)
value=6
X=np.log(x * (np.e**2-1) +1)

x=np.arange(0,2,0.01)
fx=pow(np.e,x) / (pow(np.e,2) - 1)

print(X)
plt.plot(x,fx)
plt.hist(X, bins=100, density=True)
plt.show()
# Out:
# [1.98835242 0.82438809 1.96023642 ... 0.3625061  1.33887204 1.71575222]

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.25.2)

# %%
import numpy as np
import matplotlib.pyplot as plt


N=1000000
lambda1=1/28
x=np.random.uniform(0,1,N)
value=4
Xexp=-np.log(x)/lambda1

count=sum(Xexp<4)
print(Xexp)

prob=count/N
print("a probabilidade e",prob)

Probana=1-np.exp(-lambda1*value)
print("a probabilidade analítica e",Probana)

X=np.arange(0, 200, 1)
fx=lambda1*np.exp(-lambda1*X)
plt.plot(X,fx)
plt.show()
# Out:
# [34.1468604   3.25507769 11.78598751 ...  3.11848773 11.29779796
#   2.83434418]
# a probabilidade e 0.132571
# a probabilidade analítica e 0.1331221002498184
